# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import os

tableau_resultat = pd.read_csv('../output_data/resultats.csv', index_col=0)
print(tableau_resultat)
# Out:
#                  slice_index  sam_dice  sam_precision  sam_recall  sam_HD100  \
# BraTS2021_00000           54  0.619775       1.000000    0.449039  15.231546
# BraTS2021_00002          105  0.876907       0.988731    0.787807  16.492423
#
#                  sam_AVG_seg2gt  sam_AVG_gt2seg  medsam_dice  \
# BraTS2021_00000        7.570526        0.000000     0.770984
# BraTS2021_00002        3.734247        0.116526     0.935961
#
#                  medsam_precision  medsam_recall  medsam_HD100  \
# BraTS2021_00000          0.964981       0.641933          12.0
# BraTS2021_00002          0.957888       0.915014           5.0
#
#                  medsam_AVG_seg2gt  medsam_AVG_gt2seg
# BraTS2021_00000           3.512051           0.192175
# BraTS2021_00002           0.878825           0.398179
